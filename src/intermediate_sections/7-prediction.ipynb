# %% [markdown]
# # Prediction
#
# In this section, we apply the training dataset `balanced.csv` to the best model we have found (Random Forest) and make predictions on the test dataset `to_predict.csv`.

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

# %%
df_train = pd.read_csv('../data/balanced_2.csv')
df_train.head()
# Out:
#    sex  is_employed  income  num_vehicles   age  state_of_res  gas_usage  \
# 0    1            1   -0.35           0.0  0.04             0       2.67
# 1    0            0   -0.33           0.0  0.78             0      -0.61
# 2    0            1   -0.37           2.0  0.13             0      -0.02
# 3    0            0   -0.08           1.0  0.92             0       1.25
# 4    1            1   -0.06           2.0  0.59             0      -0.61
#
#    rooms  marital_status_Divorced/Separated  marital_status_Married  \
# 0      3                                  0                       0
# 1      6                                  1                       0
# 2      3                                  0                       0
# 3      2                                  0                       0
# 4      2                                  1                       0
#
#    marital_status_Never married  marital_status_Widowed  \
# 0                             1                       0
# 1                             0                       0
# 2                             1                       0
# 3                             0                       1
# 4                             0                       0
#
#    housing_type_Homeowner free and clear  \
# 0                                      1
# 1                                      0
# 2                                      0
# 3                                      1
# 4                                      0
#
#    housing_type_Homeowner with mortgage/loan  \
# 0                                          0
# 1                                          0
# 2                                          1
# 3                                          0
# 4                                          0
#
#    housing_type_Occupied with no rent  housing_type_Rented  health_ins
# 0                                   0                    0           1
# 1                                   0                    1           1
# 2                                   0                    0           1
# 3                                   0                    0           1
# 4                                   0                    1           1

# %%
X_train = df_train.drop('health_ins', axis=1)
y_train = df_train['health_ins']

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
df_to_predict = pd.read_csv('../data/to_predict.csv')
df_to_predict.head()
# Out:
#          custid  sex  is_employed  income  num_vehicles   age  state_of_res  \
# 0  001115999_01    1            0   -0.06          0.17  0.78      0.062500
# 1  000566299_01    1            1    0.22          0.17  0.24      0.625000
# 2  001397329_01    0            1    4.33          0.50  0.42      0.104167
# 3  000843100_01    0            0   -0.79          0.17  0.55      0.083333
# 4  000260071_03    1            1    0.22          0.67  0.18      0.604167
#
#    gas_usage  rooms  marital_status_Divorced/Separated  \
# 0      -0.27    1.0                                  0
# 1       0.11    0.8                                  0
# 2       0.87    0.2                                  0
# 3      -0.08    0.2                                  0
# 4       2.20    0.0                                  0
#
#    marital_status_Married  marital_status_Never married  \
# 0                       1                             0
# 1                       0                             1
# 2                       1                             0
# 3                       1                             0
# 4                       1                             0
#
#    marital_status_Widowed  housing_type_Homeowner free and clear  \
# 0                       0                                      1
# 1                       0                                      0
# 2                       0                                      0
# 3                       0                                      1
# 4                       0                                      0
#
#    housing_type_Homeowner with mortgage/loan  \
# 0                                          0
# 1                                          0
# 2                                          1
# 3                                          0
# 4                                          1
#
#    housing_type_Occupied with no rent  housing_type_Rented
# 0                                   0                    0
# 1                                   0                    1
# 2                                   0                    0
# 3                                   0                    0
# 4                                   0                    0

# %%
ids = df_to_predict['custid']
X = df_to_predict.drop('custid', axis=1)

# %%
predictions = model.predict(X)
predictions = ['TRUE' if p == 1 else 'FALSE' for p in predictions]
output = pd.DataFrame({'custid': ids, 'health_ins': predictions})
output
# Out:
#            custid health_ins
# 0    001115999_01       TRUE
# 1    000566299_01      FALSE
# 2    001397329_01       TRUE
# 3    000843100_01       TRUE
# 4    000260071_03       TRUE
# ..            ...        ...
# 799  000961606_04      FALSE
# 800  001063357_01       TRUE
# 801  000613999_02       TRUE
# 802  000087463_03       TRUE
# 803  001080446_02      FALSE
#
# [804 rows x 2 columns]

# %%
pd.DataFrame(output).to_csv('../data/predictions.csv', index=False)

# %% [markdown]
# Our predictions are saved in a file named `predictions.csv` and this file is ready to be submitted to the competition.
